# %% [markdown]
# **INFERENTAIL STATISTICS**

# %%
#It is a process ofusing data analysis to deduce properties of an underlying probability distribution.
#three main ways to learn about inferentail statistics are.
#*Point Estimation
#*Interval Estimation
#*Hypothesis Testing

# %%
#Estimation:
#Estimation represents themethod of obtaining the most realible parameter using static.

# %%
#Interval Estimation:An interval estimate is defined by two numbers ,with in which in population parameter is said to be lie.

# %%
#*Point Estimation:
#point estimators can be the single vlues that estimate the unknown parameter from the static.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("/content/Life Expectancy Data.csv")
df.head()
# Out:
#        Country  Year      Status  Adult Mortality  infant deaths  Alcohol  \
# 0  Afghanistan  2015  Developing            263.0             62     0.01
# 1  Afghanistan  2014  Developing            271.0             64     0.01
# 2  Afghanistan  2013  Developing            268.0             66     0.01
# 3  Afghanistan  2012  Developing            272.0             69     0.01
# 4  Afghanistan  2011  Developing            275.0             71     0.01
#
#    percentage expenditure  Hepatitis B  Measles    BMI   ...  \
# 0               71.279624         65.0      1154   19.1  ...
# 1               73.523582         62.0       492   18.6  ...
# 2               73.219243         64.0       430   18.1  ...
# 3               78.184215         67.0      2787   17.6  ...
# 4                7.097109         68.0      3013   17.2  ...
#
#    Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# 0               8.16         65.0        0.1  584.259210  33736494.0
# ...

# %%
df["Life expectancy "]
# Out:
# 0       65.0
# 1       59.9
# 2       59.9
# 3       59.5
# 4       59.2
#         ...
# 2933    44.3
# 2934    44.5
# 2935    44.8
# 2936    45.3
# 2937    46.0
# Name: Life expectancy , Length: 2938, dtype: float64

# %%
df.columns
# Out:
# Index(['Country', 'Year', 'Status', 'Adult Mortality', 'infant deaths',
#        'Alcohol', 'percentage expenditure', 'Hepatitis B', 'Measles ', ' BMI ',
#        'under-five deaths ', 'Polio', 'Total expenditure', 'Diphtheria ',
#        ' HIV/AIDS', 'GDP', 'Population', ' thinness  1-19 years',
#        ' thinness 5-9 years', 'Income composition of resources', 'Schooling',
#        'Life expectancy '],
#       dtype='object')

# %%
df.shape
# Out:
# (2938, 22)

# %%
df.isnull().sum()
# Out:
# Country                              0
# Year                                 0
# Status                               0
# Adult Mortality                     10
# infant deaths                        0
# Alcohol                            194
# percentage expenditure               0
# Hepatitis B                        553
# Measles                              0
#  BMI                                34
# under-five deaths                    0
# Polio                               19
# Total expenditure                  226
# Diphtheria                          19
#  HIV/AIDS                            0
# GDP                                448
# Population                         652
#  thinness  1-19 years               34
#  thinness 5-9 years                 34
# Income composition of resources    167
# Schooling                          163
# Life expectancy                     10
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# Country                            0
# Year                               0
# Status                             0
# Adult Mortality                    0
# infant deaths                      0
# Alcohol                            0
# percentage expenditure             0
# Hepatitis B                        0
# Measles                            0
#  BMI                               0
# under-five deaths                  0
# Polio                              0
# Total expenditure                  0
# Diphtheria                         0
#  HIV/AIDS                          0
# GDP                                0
# Population                         0
#  thinness  1-19 years              0
#  thinness 5-9 years                0
# Income composition of resources    0
# Schooling                          0
# Life expectancy                    0
# dtype: int64

# %%
df.shape
# Out:
# (1649, 22)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df["Life expectancy "].mean()
# Out:
# 69.3023044269254

# %%
df.describe()
# Out:
#               Year  Adult Mortality  infant deaths      Alcohol  \
# count  1649.000000      1649.000000    1649.000000  1649.000000
# mean   2007.840509       168.215282      32.553062     4.533196
# std       4.087711       125.310417     120.847190     4.029189
# min    2000.000000         1.000000       0.000000     0.010000
# 25%    2005.000000        77.000000       1.000000     0.810000
# 50%    2008.000000       148.000000       3.000000     3.790000
# 75%    2011.000000       227.000000      22.000000     7.340000
# max    2015.000000       723.000000    1600.000000    17.870000
#
#        percentage expenditure  Hepatitis B       Measles          BMI   \
# count             1649.000000  1649.000000    1649.000000  1649.000000
# mean               698.973558    79.217708    2224.494239    38.128623
# std               1759.229336    25.604664   10085.802019    19.754249
# min                  0.000000     2.000000       0.000000     2.000000
# ...

# %%
sample=df[df.Country== "Afghanistan"].sample(10,random_state=2)
sample
# Out:
#         Country  Year      Status  Adult Mortality  infant deaths  Alcohol  \
# 12  Afghanistan  2003  Developing            295.0             87     0.01
# 4   Afghanistan  2011  Developing            275.0             71     0.01
# 5   Afghanistan  2010  Developing            279.0             74     0.01
# 0   Afghanistan  2015  Developing            263.0             62     0.01
# 9   Afghanistan  2006  Developing            295.0             84     0.03
# 3   Afghanistan  2012  Developing            272.0             69     0.01
# 1   Afghanistan  2014  Developing            271.0             64     0.01
# 10  Afghanistan  2005  Developing            291.0             85     0.02
# 7   Afghanistan  2008  Developing            287.0             80     0.03
# 14  Afghanistan  2001  Developing            316.0             88     0.01
#
#     percentage expenditure  Hepatitis B  Measles    BMI   ...  \
# 12               11.089053         65.0       798   13.4  ...
# ...

# %%
sample["Life expectancy "].mean()
# Out:
# 58.709999999999994

# %%
df1=pd.read_csv("/content/hotel_bookings.csv")
df1.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                      27.0                        1.0
# 1                      27.0                        1.0
# 2                      27.0                        1.0
# 3                      27.0                        1.0
# 4                      27.0                        1.0
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                      0.0                   0.0     2.0  ...    No Deposit
# ...

# %%
df1.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
df1["hotel"].unique()
# Out:
# array(['Resort Hotel'], dtype=object)
